# %%
import matplotlib.pyplot as plt
import numpy as np

# Reflectance values and their corresponding DNA codewords
indices = np.arange(1, 21)
reflectance_values = [
    0.8762, 0.8384, 0.8699, 0.9296, 0.9183, 0.9765, 0.9120, 0.9590,
    0.9968, 1.0933, 1.0962, 1.1437, 1.1710, 1.1686, 1.1893, 1.2362,
    1.2074, 1.2529, 1.3288, 1.3461
]
dna_codewords = [
    'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
    'C', 'C', 'C', 'C', 'A', 'T'
]

# DNA to binary mapping
codeword_to_binary = {'C': '01', 'A': '00', 'T': '11'}
binary_encodings = [codeword_to_binary[cw] for cw in dna_codewords]

# Convert binary encodings to numerical values for plotting
binary_values = np.array([int(bw, 2) for bw in binary_encodings])

# Plotting
plt.figure(figsize=(12, 6))
plt.stem(indices, binary_values, basefmt=" ", use_line_collection=False)
plt.xticks(indices)
plt.yticks([0, 1, 3], ['00 (A)', '01 (C)', '11 (T)'])
plt.xlabel('Index')
plt.ylabel('Binary Encoding')
plt.title('Global DNA Encoding of Spectral Data')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 25
#      23 # Plotting
#      24 plt.figure(figsize=(12, 6))
# ---> 25 plt.stem(indices, binary_values, basefmt=" ", use_line_collection=False)
#      26 plt.xticks(indices)
#      27 plt.yticks([0, 1, 3], ['00 (A)', '01 (C)', '11 (T)'])
#
# TypeError: stem() got an unexpected keyword argument 'use_line_collection'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example DNA sequences
sequences = {
    'Sequence': ['ATCG', 'CGTA', 'GATC', 'TACG'],
    'A': [1, 1, 1, 1],
    'T': [1, 1, 1, 1],
    'C': [1, 1, 1, 1],
    'G': [1, 1, 1, 1]
}

# Create a DataFrame
df = pd.DataFrame(sequences)
# Set the index of the DataFrame to 'Sequence'
df.set_index('Sequence', inplace=True)

# Plotting
df.plot(kind='bar', figsize=(10, 6))
plt.title('Nucleotide Counts in DNA Sequences')
plt.xlabel('Sequence')
plt.ylabel('Count')
plt.legend(title='Nucleotide')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Reflectance values and their corresponding DNA codewords
indices = np.arange(1, 21)
reflectance_values = [
    0.8762, 0.8384, 0.8699, 0.9296, 0.9183, 0.9765, 0.9120, 0.9590,
    0.9968, 1.0933, 1.0962, 1.1437, 1.1710, 1.1686, 1.1893, 1.2362,
    1.2074, 1.2529, 1.3288, 1.3461
]
dna_codewords = [
    'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
    'C', 'C', 'C', 'C', 'A', 'T'
]

# DNA to binary mapping
codeword_to_binary = {'C': '01', 'A': '00', 'T': '11'}
binary_encodings = [codeword_to_binary[cw] for cw in dna_codewords]

# Convert binary encodings to numerical values for plotting
binary_values = np.array([int(bw, 2) for bw in binary_encodings])

# Plotting the binary encodings
plt.figure(figsize=(12, 6))

# Plot binary encodings
plt.subplot(1, 2, 1)
plt.stem(indices, binary_values, basefmt=" ", use_line_collection=True)
plt.xticks(indices)
plt.yticks([0, 1, 3], ['00 (A)', '01 (C)', '11 (T)'])
plt.xlabel('Index')
plt.ylabel('Binary Encoding')
plt.title('Binary Encoding of DNA Codewords')
plt.grid(True)

# Plot reflectance values
plt.subplot(1, 2, 2)
plt.plot(indices, reflectance_values, marker='o', linestyle='-', color='b')
plt.xlabel('Index')
plt.ylabel('Reflectance')
plt.title('Reflectance Values of DNA Codewords')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 28
#      26 # Plot binary encodings
#      27 plt.subplot(1, 2, 1)
# ---> 28 plt.stem(indices, binary_values, basefmt=" ", use_line_collection=True)
#      29 plt.xticks(indices)
#      30 plt.yticks([0, 1, 3], ['00 (A)', '01 (C)', '11 (T)'])
#
# TypeError: stem() got an unexpected keyword argument 'use_line_collection'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Reflectance values and their corresponding DNA codewords
indices = np.arange(1, 21)
reflectance_values = [
    0.8762, 0.8384, 0.8699, 0.9296, 0.9183, 0.9765, 0.9120, 0.9590,
    0.9968, 1.0933, 1.0962, 1.1437, 1.1710, 1.1686, 1.1893, 1.2362,
    1.2074, 1.2529, 1.3288, 1.3461
]
dna_codewords = [
    'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C', 'C',
    'C', 'C', 'C', 'C', 'A', 'T'
]

# DNA to binary mapping
codeword_to_binary = {'C': '01', 'A': '00', 'T': '11'}
binary_encodings = [codeword_to_binary[cw] for cw in dna_codewords]

# Convert binary encodings to numerical values for plotting
binary_values = np.array([int(bw, 2) for bw in binary_encodings])

# Plotting the binary encodings
plt.figure(figsize=(12, 6))

# Plot binary encodings
plt.subplot(1, 2, 1)
plt.stem(indices, binary_values, basefmt=" ", linefmt='b-', markerfmt='bo')
plt.xticks(indices)
plt.yticks([0, 1, 3], ['00 (A)', '01 (C)', '11 (T)'])
plt.xlabel('Index')
plt.ylabel('Binary Encoding')
plt.title('Binary Encoding of DNA Codewords')
plt.grid(True)

# Plot reflectance values
plt.subplot(1, 2, 2)
plt.plot(indices, reflectance_values, marker='o', linestyle='-', color='b')
plt.xlabel('Index')
plt.ylabel('Reflectance')
plt.title('Reflectance Values of DNA Codewords')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np

# Define the reflectance values
reflectance_values = np.array([
    0.8762, 0.8384, 0.8699, 0.9296, 0.9183, 0.9765, 0.912, 0.959, 0.9968, 
    1.0933, 1.0962, 1.1437, 1.171, 1.1686, 1.1893, 1.2362, 1.2074, 1.2529, 
    1.3288, 1.3461, 1.2991, 1.2659, 1.3126, 1.377, 1.3723, 1.3598, 1.3598, 
    1.4118, 1.4158, 1.4428, 1.4961, 1.5587, 1.5729, 1.5763, 1.5687, 1.6025, 
    1.6862, 1.8127, 1.8688, 1.9359, 1.9913, 2.0394, 2.0651, 2.1423, 2.2148, 
    2.2683, 2.3086, 2.417, 2.5117, 2.534, 2.5503, 2.6226, 2.6582, 2.679, 
    2.6868, 2.6728, 2.6499, 2.6658, 2.6704, 2.6562, 2.6331, 2.6535, 2.6322, 
    2.6059, 2.6082, 2.6156, 2.6014, 2.5993, 2.6046, 2.614, 2.6093, 2.6232, 
    2.5935, 2.581, 2.5963, 2.6132, 2.6293, 2.6515, 2.6267, 2.6307, 2.6326, 
    2.631, 2.6266, 2.6502, 2.6795, 2.6679, 2.6123, 2.5901, 2.5691
])

# Constants
rho = 0.75
Nb = 80  # Number of bands
k = 2
p = 2

# Calculate thresholds
average_reflectance = np.mean(reflectance_values)
T0 = rho * average_reflectance
Tl = np.max(reflectance_values) / k
Tr = np.min(reflectance_values) / p

# Define encoding function
def encode_reflectance(value):
    if Tr <= value < T0:
        return 'C'
    elif T0 <= value < Tl:
        return 'A'
    elif Tl <= value < Tr:
        return 'G'
    else:
        return 'T'

# Apply encoding to all reflectance values
encoded_values = [encode_reflectance(value) for value in reflectance_values]

# Create a DataFrame to view the results
df = pd.DataFrame({
    'Reflectance': reflectance_values,
    'DNA Codeword': encoded_values
})

print(df)
# Out:
#     Reflectance DNA Codeword
# 0        0.8762            C
# 1        0.8384            C
# 2        0.8699            C
# 3        0.9296            C
# 4        0.9183            C
# ..          ...          ...
# 84       2.6795            T
# 85       2.6679            T
# 86       2.6123            T
# 87       2.5901            T
# 88       2.5691            T
#
# [89 rows x 2 columns]

# %%
import pandas as pd
import numpy as np

# Load the CSV file
df = pd.read_csv('tap_water.csv')

# Extract reflectance values from the DataFrame
reflectance_values = df['Reflectance'].values

# Constants
rho = 0.75
Nb = 80  # Number of bands
k = 2
p = 2

# Calculate thresholds
average_reflectance = np.mean(reflectance_values)
T0 = rho * average_reflectance
Tl = np.max(reflectance_values) / k
Tr = np.min(reflectance_values) / p

# Define encoding function
def encode_reflectance(value):
    if Tr <= value < T0:
        return 'C'
    elif T0 <= value < Tl:
        return 'A'
    elif Tl <= value < Tr:
        return 'G'
    else:
        return 'T'

# Apply encoding to all reflectance values
encoded_values = [encode_reflectance(value) for value in reflectance_values]

# Add encoded values to the DataFrame
df['DNA Codeword'] = encoded_values

# Save the results to a new CSV file
df.to_csv('tap_water_encoded.csv', index=False)

print("Encoding complete. Results saved to 'tap_water_encoded.csv'.")
# Out:
# Encoding complete. Results saved to 'tap_water_encoded.csv'.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the encoded CSV file
df = pd.read_csv('tap_water_encoded.csv')

# Extract reflectance values and DNA codewords
reflectance_values = df['Reflectance'].values
dna_codewords = df['DNA Codeword'].values

# Define DNA to binary mapping
codeword_to_binary = {'C': '01', 'A': '00', 'T': '11', 'G': '10'}
binary_encodings = [codeword_to_binary[cw] for cw in dna_codewords]

# Convert binary encodings to numerical values for plotting
binary_values = np.array([int(bw, 2) for bw in binary_encodings])

# Plotting the binary encodings and reflectance values
plt.figure(figsize=(14, 7))

# Plot binary encodings
plt.subplot(1, 2, 1)
plt.plot(binary_values, marker='o', linestyle='-', color='b')
plt.xlabel('Index')
plt.ylabel('Binary Encoding')
plt.title('Binary Encoding of DNA Codewords')
plt.yticks([0, 1, 2, 3], ['00 (A)', '01 (C)', '10 (G)', '11 (T)'])
plt.grid(True)

# Plot reflectance values
plt.subplot(1, 2, 2)
plt.plot(reflectance_values, marker='o', linestyle='-', color='b')
plt.xlabel('Index')
plt.ylabel('Reflectance')
plt.title('Reflectance Values of DNA Codewords')
plt.grid(True)

plt.tight_layout()
plt.show()
