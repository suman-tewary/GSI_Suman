# %% [markdown]
# # MATURE APPLE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
mature_apple = pd.read_csv('/content/drive/MyDrive/Dataset_of_Apple/mature_apple (1).txt', sep='\t', names=['wavelength', 'Reflectance'])
mature_apple
# Out:
#      wavelength  Reflectance
# 0         306.5      16.5899
# 1         308.0      13.9647
# 2         309.4      13.8249
# 3         310.9      13.8528
# 4         312.3      12.6294
# ..          ...          ...
# 507      1103.7     102.8571
# 508      1105.4     114.2857
# 509      1107.1     113.4454
# 510      1108.8     100.0000
# 511      1110.6     105.6122
#
# [512 rows x 2 columns]

# %%
# Load the data
mature_apple = '/content/drive/MyDrive/Dataset_of_Apple/mature_apple (1).txt'

# Read the data into pandas dataframes
mature_df = pd.read_csv(mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# Plotting the data for "Mature Apple"
plt.figure(figsize=(8, 4))

# Now plot
plt.subplot(1, 2, 2) #plt.subplot (nrows, ncols, index)
plt.plot(mature_df['Wavelength'], mature_df['Reflectance'], label='Mature Apple', color='green')
plt.xlabel('Wavelength')
plt.ylabel('Reflectance')
plt.title('Mature Apple')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-772b90ff0995>:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mature_df = pd.read_csv(mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# %% [markdown]
# # For Late Mature Apple

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
late_mature_apple = pd.read_csv('/content/drive/MyDrive/Dataset_of_Apple/late_mature_apple (1).txt', sep='\t', names=['wavelength', 'Reflectance'])
late_mature_apple
# Out:
#      wavelength  Reflectance
# 0         306.5      17.1429
# 1         308.0      16.4423
# 2         309.4      16.5899
# 3         310.9      15.7576
# 4         312.3      15.7025
# ..          ...          ...
# 507      1103.7      77.1429
# 508      1105.4      78.8235
# 509      1107.1      76.8000
# 510      1108.8      72.9167
# 511      1110.6      77.1429
#
# [512 rows x 2 columns]

# %%
# Load the data
late_mature_apple = '/content/drive/MyDrive/Dataset_of_Apple/late_mature_apple (1).txt'

# Read the data into pandas dataframes
mature_df = pd.read_csv(late_mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# Plotting the data for "Late Mature Apple"
plt.figure(figsize=(8, 4))

# Now plot
plt.subplot(1, 2, 2) #plt.subplot (nrows, ncols, index)
plt.plot(mature_df['Wavelength'], mature_df['Reflectance'], label='Late Mature Apple', color='green')
plt.xlabel('Wavelength')
plt.ylabel('Reflectance')
plt.title('Late Mature Apple')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-427666ed6d7a>:5: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mature_df = pd.read_csv(late_mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# %% [markdown]
# # First order derivative

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load your data
late_mature_apple = np.loadtxt('/content/drive/MyDrive/Dataset_of_Apple/mature_apple (1).txt')
mature_apple = np.loadtxt('/content/drive/MyDrive/Dataset_of_Apple/late_mature_apple (1).txt')

# Calculate first order derivatives
 # dfdx = np.gradient (fx, dx), where fx = Reflectance values and dx= Wabelength values
late_mature_apple_first_derivative = np.gradient(late_mature_apple[:, 1], late_mature_apple[:, 0])

 # dfdx = np.gradient (fx, dx), where fx = Reflectance values and dx= Wabelength values
mature_apple_first_derivative = np.gradient(mature_apple[:, 1], mature_apple[:, 0])


# Plot the first order derivatives
plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1) #plt.subplot (nrows, ncols, index)
plt.plot(late_mature_apple[:, 0], late_mature_apple_first_derivative, label='Late Mature Apple', color='blue')
plt.xlabel('Wavelength (nm)')
plt.ylabel('First Derivative of Reflectance')
plt.title('First Order Derivative for Late Mature Apple')
plt.legend()

plt.subplot(1, 2, 2) #plt.subplot (nrows, ncols, index)
plt.plot(mature_apple[:, 0], mature_apple_first_derivative, label='Mature Apple', color='green')
plt.xlabel('Wavelength (nm)')
plt.ylabel('First Derivative of Reflectance')
plt.title('First Order Derivative for Mature Apple')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Second order derivative

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load your data
late_mature_apple = np.loadtxt('/content/drive/MyDrive/Dataset_of_Apple/mature_apple (1).txt')
mature_apple = np.loadtxt('/content/drive/MyDrive/Dataset_of_Apple/late_mature_apple (1).txt')

# Calculate second order derivatives
# dfdx = np.gradient (fx, dx) where, fx contains = first order derivatives of the Reflectance values (late mature apple)
# dx contains = Wabelength values
late_mature_apple_second_derivative = np.gradient(late_mature_apple_first_derivative, late_mature_apple[:, 0])

# dfdx = np.gradient (fx, dx) where, fx contains = first order derivatives of the Reflectance values (mature apple)
# dx contains = Wabelength values
mature_apple_second_derivative = np.gradient(mature_apple_first_derivative, mature_apple[:, 0])

# Plot the second order derivatives
plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1) #plt.subplot (nrows, ncols, index)
plt.plot(late_mature_apple[:, 0], late_mature_apple_second_derivative, label='Late Mature Apple', color='blue')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Second Derivative of Reflectance')
plt.title('Second Order Derivative for Late Mature Apple')
plt.legend()

plt.subplot(1, 2, 2) #plt.subplot (nrows, ncols, index)
plt.plot(mature_apple[:, 0], mature_apple_second_derivative, label='Mature Apple', color='green')
plt.xlabel('Wavelength (nm)')
plt.ylabel('Second Derivative of Reflectance')
plt.title('Second Order Derivative for Mature Apple')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Differenciate by using SAM(Spectral Angle Mapper)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# Load the data for "Mature Apple"
mature_apple = '/content/drive/MyDrive/Dataset_of_Apple/mature_apple (1).txt'
mature_df = pd.read_csv(mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# Load the data for "Late Mature Apple"
late_mature_apple = '/content/drive/MyDrive/Dataset_of_Apple/late_mature_apple (1).txt'
late_mature_df = pd.read_csv(late_mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# Make sure the Wavelength values are the same for both datasets
# If not, you may need to interpolate to match wavelengths between the two datasets

# Define the SAM function
def spectral_angle_mapper(spectrum1, spectrum2):
    dot_product = np.dot(spectrum1, spectrum2)
    magnitude1 = np.linalg.norm(spectrum1)
    magnitude2 = np.linalg.norm(spectrum2)
    angle = math.acos(dot_product / (magnitude1 * magnitude2))
    return angle

# Calculate SAM for Reflectance values
sam_value = spectral_angle_mapper(mature_df['Reflectance'], late_mature_df['Reflectance'])

# Plotting both spectra for comparison
plt.figure(figsize=(8, 4))

# Plot Mature Apple
plt.plot(mature_df['Wavelength'], mature_df['Reflectance'], label='Mature Apple', color='green')

# Plot Late Mature Apple
plt.plot(late_mature_df['Wavelength'], late_mature_df['Reflectance'], label='Late Mature Apple', color='blue')

# Add labels and title
plt.xlabel('Wavelength (nm)')
plt.ylabel('Reflectance')
plt.title(f'Spectral Comparison (SAM Angle = {sam_value:.4f} radians)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-1-23b46aff3675>:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mature_df = pd.read_csv(mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])
# <ipython-input-1-23b46aff3675>:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   late_mature_df = pd.read_csv(late_mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# %% [markdown]
# # By using Distance Function

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# Load the data for "Mature Apple"
mature_apple = '/content/drive/MyDrive/Dataset_of_Apple/mature_apple (1).txt'
mature_df = pd.read_csv(mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# Load the data for "Late Mature Apple"
late_mature_apple = '/content/drive/MyDrive/Dataset_of_Apple/late_mature_apple (1).txt'
late_mature_df = pd.read_csv(late_mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# Define the SAM function
def spectral_angle_mapper(spectrum1, spectrum2):
    dot_product = np.dot(spectrum1, spectrum2)
    magnitude1 = np.linalg.norm(spectrum1)
    magnitude2 = np.linalg.norm(spectrum2)
    angle = math.acos(dot_product / (magnitude1 * magnitude2))
    return angle

# Calculate SAM for Reflectance values as initial distance measure d_k
sam_value = spectral_angle_mapper(mature_df['Reflectance'], late_mature_df['Reflectance'])

# Generate a series of eta values (parameter values) for demonstration
eta_values = np.linspace(0, 1, 10)  # Assuming eta values range from 0 to 1
sam_distances = np.array([spectral_angle_mapper(mature_df['Reflectance'], late_mature_df['Reflectance'] * (1 + e)) for e in eta_values])

# Equation (1): Normalize and apply inequality
eta_min, eta_max = eta_values[0], eta_values[-1]
dk_min, dk_max = sam_distances[0], sam_distances[-1]

normalized_distances = (sam_distances - dk_min) / (dk_max - dk_min)
eta_ratios = (eta_values - eta_min) / (eta_max - eta_min)
inequality_satisfied = np.all(normalized_distances >= eta_ratios)

print("Inequality (1) satisfied for all eta values:" if inequality_satisfied else "Inequality (1) not satisfied for all eta values.")

# Equation (2): Calculate eta_sat where distance function reaches its maximum
eta_sat = eta_values[np.argmax(sam_distances)]
print("Saturation point (eta_sat):", eta_sat)

# Equation (3): Calculate dynamic range dnr
dnr = dk_max - dk_min
print("Dynamic range (dnr):", dnr)

# Plotting the distance function over eta values
plt.figure(figsize=(8, 4))
plt.plot(eta_values, sam_distances, label='Distance function d_k(eta)', color='purple')
plt.xlabel('Eta')
plt.ylabel('Distance (SAM)')
plt.title(f'Distance Function with Dynamic Range (dnr = {dnr:.4f})')
plt.axvline(x=eta_sat, color='red', linestyle='--', label=f'Saturation Point (eta_sat = {eta_sat:.2f})')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-2-a34862ed8252>:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mature_df = pd.read_csv(mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])
# <ipython-input-2-a34862ed8252>:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   late_mature_df = pd.read_csv(late_mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])
# <ipython-input-2-a34862ed8252>:33: RuntimeWarning: divide by zero encountered in divide
#   normalized_distances = (sam_distances - dk_min) / (dk_max - dk_min)
# <ipython-input-2-a34862ed8252>:33: RuntimeWarning: invalid value encountered in divide
#   normalized_distances = (sam_distances - dk_min) / (dk_max - dk_min)
# Inequality (1) not satisfied for all eta values.
# Saturation point (eta_sat): 0.3333333333333333
# ...

# %% [markdown]
# # GMC Distance Function

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the data for "Mature Apple"
mature_apple = '/content/drive/MyDrive/Dataset_of_Apple/mature_apple (1).txt'
mature_df = pd.read_csv(mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# Load the data for "Late Mature Apple"
late_mature_apple = '/content/drive/MyDrive/Dataset_of_Apple/late_mature_apple (1).txt'
late_mature_df = pd.read_csv(late_mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])

# Define the GMC distance function
def gmc_distance(spectrum1, spectrum2):
    differences = spectrum1 - spectrum2
    gmc_values = (differences ** 2) / (1 + differences ** 2)
    return np.sum(gmc_values)

# Calculate GMC for Reflectance values as initial distance measure d_k
gmc_value = gmc_distance(mature_df['Reflectance'].values, late_mature_df['Reflectance'].values)

# Generate a series of eta values (parameter values) for demonstration
eta_values = np.linspace(0, 1, 10)  # Assuming eta values range from 0 to 1
gmc_distances = np.array([gmc_distance(mature_df['Reflectance'].values, late_mature_df['Reflectance'].values * (1 + e)) for e in eta_values])

# Equation (1): Normalize and apply inequality
eta_min, eta_max = eta_values[0], eta_values[-1]
dk_min, dk_max = gmc_distances[0], gmc_distances[-1]

normalized_distances = (gmc_distances - dk_min) / (dk_max - dk_min)
eta_ratios = (eta_values - eta_min) / (eta_max - eta_min)
inequality_satisfied = np.all(normalized_distances >= eta_ratios)

print("Inequality (1) satisfied for all eta values:" if inequality_satisfied else "Inequality (1) not satisfied for all eta values.")

# Equation (2): Calculate eta_sat where distance function reaches its maximum
eta_sat = eta_values[np.argmax(gmc_distances)]
print("Saturation point (eta_sat):", eta_sat)

# Equation (3): Calculate dynamic range dnr
dnr = dk_max - dk_min
print("Dynamic range (dnr):", dnr)

# Plotting the distance function over eta values
plt.figure(figsize=(8, 4))
plt.plot(eta_values, gmc_distances, label='Distance function d_k(eta)', color='purple')
plt.xlabel('Eta')
plt.ylabel('Distance (GMC)')
plt.title(f'Distance Function with Dynamic Range (dnr = {dnr:.4f})')
plt.axvline(x=eta_sat, color='red', linestyle='--', label=f'Saturation Point (eta_sat = {eta_sat:.2f})')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-1-772f627aa6cb>:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   mature_df = pd.read_csv(mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])
# <ipython-input-1-772f627aa6cb>:11: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   late_mature_df = pd.read_csv(late_mature_apple, delim_whitespace=True, names=['Wavelength', 'Reflectance'])
# Inequality (1) not satisfied for all eta values.
# Saturation point (eta_sat): 1.0
# Dynamic range (dnr): 22.37929311704329
