# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from datetime import datetime, timedelta

def perform_pca(file_path):
    # Load the CSV file
    data = pd.read_csv(file_path)
    
    # Drop rows with missing values
    data_cleaned = data.dropna()
    
    # Extract reflectance values (exclude non-numeric columns like sample IDs)
    reflectance_matrix = data_cleaned.iloc[:, 1:].values  # Adjust slicing as per your dataset
    wavelengths = data_cleaned.columns[1:]  # Extract wavelength column names
    
    # Normalize the reflectance data (standardize: mean=0, std=1)
    reflectance_normalized = (reflectance_matrix - np.mean(reflectance_matrix, axis=0)) / np.std(reflectance_matrix, axis=0)
    
    # Perform PCA
    pca = PCA()
    pca.fit(reflectance_normalized)
    
    # Extract explained variance and principal components
    explained_variance = pca.explained_variance_ratio_
    principal_components = pca.components_
    
    # Get top 10 wavelengths for each of the first 5 PCs
    pc_results = {}
    for pc_index in range(5):
        loading_scores = principal_components[pc_index]  # Loadings for the current PC
        important_wavelengths = sorted(zip(wavelengths, loading_scores), key=lambda x: abs(x[1]), reverse=True)[:10]
        pc_results[f"PC{pc_index + 1}"] = important_wavelengths
    
    return explained_variance[:5], pc_results

def generate_report(file_paths):
    # Initialize report data
    report_pc_percentages = []
    report_pc_wavelengths = []
    
    # Process each file (day-by-day)
    for day, file_path in enumerate(file_paths, start=1):
        print(f"Processing Day {day}...")
        explained_variance, pc_results = perform_pca(file_path)
        
        # Add explained variance percentages to the report
        report_pc_percentages.append([f"Day {day}"] + [f"{variance * 100:.2f}%" for variance in explained_variance])
        
        # Add top 10 wavelengths for each PC to the report
        day_wavelengths = {}
        for pc, wavelengths in pc_results.items():
            day_wavelengths[pc] = wavelengths
        report_pc_wavelengths.append((f"Day {day}", day_wavelengths))
    
    # Create a DataFrame for the PC percentages table
    pc_percentage_df = pd.DataFrame(report_pc_percentages, columns=["Day", "PC1", "PC2", "PC3", "PC4", "PC5"])
    
    # Print the report
    print("\nPCA Report: Day-by-Day Explained Variance Percentages")
    print(pc_percentage_df.to_string(index=False))
    
    print("\nPCA Report: Day-by-Day Top 10 Wavelengths for Each Principal Component")
    for day, wavelengths in report_pc_wavelengths:
        print(f"\n{day}:")
        for pc, values in wavelengths.items():
            print(f"\n{pc}:")
            for wavelength, score in values:
                print(f"Wavelength: {wavelength}, Contribution: {score:.4f}")

# Example usage
file_paths = [
    "C:\\Users\\sumat\\Desktop\\GSI Suman\\pravakar\\Filter data of Green apple\\Merged data\\merged_wavelength_reflectance 09-07-24.csv",
    "C:\\Users\\sumat\\Desktop\\GSI Suman\\pravakar\\Filter data of Green apple\\Merged data\\merged_wavelength_reflectance 12-07-24.csv",
    "C:\\Users\\sumat\\Desktop\\GSI Suman\\pravakar\\Filter data of Green apple\\Merged data\\merged_wavelength_reflectance 23-07-24.csv",
    "C:\\Users\\sumat\\Desktop\\GSI Suman\\pravakar\\Filter data of Green apple\\Merged data\\merged_wavelength_reflectance 31-07-24.csv",
    "C:\\Users\\sumat\\Desktop\\GSI Suman\\pravakar\\Filter data of Green apple\\Merged data\\merged_wavelength_reflectance 06-09-24.csv",
    "C:\\Users\\sumat\\Desktop\\GSI Suman\\pravakar\\Filter data of Green apple\\Merged data\\merged_wavelength_reflectance 03-10-24.csv"
]
generate_report(file_paths)
# Out:
# Processing Day 1...
# Processing Day 2...
# Processing Day 3...
# Processing Day 4...
# Processing Day 5...
# Processing Day 6...
#
# PCA Report: Day-by-Day Explained Variance Percentages
#   Day    PC1    PC2   PC3   PC4   PC5
# Day 1 87.30% 10.35% 1.48% 0.44% 0.20%
# Day 2 92.65%  4.68% 1.47% 0.77% 0.27%
# Day 3 95.77%  3.50% 0.44% 0.21% 0.07%
# Day 4 95.31%  2.20% 1.29% 0.90% 0.29%
# Day 5 95.80%  3.44% 0.46% 0.11% 0.10%
# Day 6 84.43% 12.10% 3.01% 0.27% 0.20%
#
# PCA Report: Day-by-Day Top 10 Wavelengths for Each Principal Component
#
# Day 1:
#
# PC1:
# Wavelength: 1869, Contribution: 0.0229
# Wavelength: 1868, Contribution: 0.0229
# Wavelength: 1870, Contribution: 0.0229
# Wavelength: 1867, Contribution: 0.0229
# Wavelength: 1513, Contribution: 0.0229
# Wavelength: 1514, Contribution: 0.0229
# Wavelength: 1512, Contribution: 0.0229
# Wavelength: 1515, Contribution: 0.0229
# Wavelength: 1503, Contribution: 0.0229
# Wavelength: 1510, Contribution: 0.0229
#
# PC2:
# Wavelength: 670, Contribution: 0.0578
# Wavelength: 671, Contribution: 0.0578
# Wavelength: 672, Contribution: 0.0578
# Wavelength: 669, Contribution: 0.0578
# Wavelength: 673, Contribution: 0.0577
# Wavelength: 679, Contribution: 0.0576
# Wavelength: 678, Contribution: 0.0576
# Wavelength: 680, Contribution: 0.0576
# Wavelength: 668, Contribution: 0.0576
# Wavelength: 674, Contribution: 0.0575
#
# PC3:
# Wavelength: 2502, Contribution: 0.0557
# Wavelength: 2501, Contribution: 0.0551
# Wavelength: 2482, Contribution: 0.0533
# Wavelength: 2483, Contribution: 0.0532
# Wavelength: 2503, Contribution: 0.0530
# Wavelength: 2500, Contribution: 0.0528
# Wavelength: 2487, Contribution: 0.0520
# Wavelength: 2481, Contribution: 0.0510
# Wavelength: 2486, Contribution: 0.0505
# Wavelength: 2484, Contribution: 0.0504
#
# PC4:
# Wavelength: 2485, Contribution: 0.0755
# Wavelength: 2498, Contribution: 0.0735
# Wavelength: 2486, Contribution: 0.0720
# Wavelength: 2484, Contribution: 0.0719
# Wavelength: 2487, Contribution: 0.0687
# Wavelength: 2499, Contribution: 0.0675
# Wavelength: 2497, Contribution: 0.0668
# Wavelength: 2469, Contribution: 0.0667
# Wavelength: 2483, Contribution: 0.0664
# Wavelength: 2458, Contribution: 0.0654
#
# PC5:
# Wavelength: 399, Contribution: 0.1340
# Wavelength: 398, Contribution: 0.1202
# Wavelength: 395, Contribution: 0.1141
# Wavelength: 394, Contribution: 0.1134
# Wavelength: 397, Contribution: 0.1126
# Wavelength: 396, Contribution: 0.1107
# Wavelength: 400, Contribution: 0.1092
# Wavelength: 384, Contribution: 0.1091
# Wavelength: 393, Contribution: 0.1087
# Wavelength: 385, Contribution: 0.1079
#
# Day 2:
#
# PC1:
# Wavelength: 1496, Contribution: 0.0222
# Wavelength: 1495, Contribution: 0.0222
# Wavelength: 1497, Contribution: 0.0222
# Wavelength: 1499, Contribution: 0.0222
# Wavelength: 1498, Contribution: 0.0222
# Wavelength: 1494, Contribution: 0.0222
# Wavelength: 1492, Contribution: 0.0222
# Wavelength: 1493, Contribution: 0.0222
# Wavelength: 1500, Contribution: 0.0222
# Wavelength: 1491, Contribution: 0.0222
#
# PC2:
# Wavelength: 639, Contribution: 0.0586
# Wavelength: 640, Contribution: 0.0585
# Wavelength: 638, Contribution: 0.0584
# Wavelength: 641, Contribution: 0.0582
# Wavelength: 637, Contribution: 0.0580
# Wavelength: 642, Contribution: 0.0579
# Wavelength: 643, Contribution: 0.0576
# Wavelength: 636, Contribution: 0.0576
# Wavelength: 644, Contribution: 0.0573
# Wavelength: 645, Contribution: 0.0570
#
# PC3:
# Wavelength: 1923, Contribution: 0.1347
# Wavelength: 1922, Contribution: 0.1345
# Wavelength: 1921, Contribution: 0.1344
# Wavelength: 1920, Contribution: 0.1343
# Wavelength: 1919, Contribution: 0.1341
# Wavelength: 1918, Contribution: 0.1337
# Wavelength: 1917, Contribution: 0.1329
# Wavelength: 1916, Contribution: 0.1319
# Wavelength: 1915, Contribution: 0.1306
# Wavelength: 1914, Contribution: 0.1292
#
# PC4:
# Wavelength: 1923, Contribution: 0.1003
# Wavelength: 1922, Contribution: 0.1002
# Wavelength: 1921, Contribution: 0.1001
# Wavelength: 1920, Contribution: 0.0990
# Wavelength: 1919, Contribution: 0.0974
# Wavelength: 1918, Contribution: 0.0958
# Wavelength: 1917, Contribution: 0.0937
# Wavelength: 1916, Contribution: 0.0912
# Wavelength: 1915, Contribution: 0.0886
# Wavelength: 1914, Contribution: 0.0857
#
# PC5:
# Wavelength: 1923, Contribution: 0.1498
# Wavelength: 1922, Contribution: 0.1482
# Wavelength: 1921, Contribution: 0.1464
# Wavelength: 1920, Contribution: 0.1447
# Wavelength: 1919, Contribution: 0.1422
# Wavelength: 1918, Contribution: 0.1396
# Wavelength: 1917, Contribution: 0.1383
# Wavelength: 1916, Contribution: 0.1360
# Wavelength: 1915, Contribution: 0.1328
# Wavelength: 1914, Contribution: 0.1283
#
# Day 3:
#
# PC1:
# Wavelength: 2237, Contribution: 0.0219
# Wavelength: 2189, Contribution: 0.0219
# Wavelength: 2236, Contribution: 0.0219
# Wavelength: 2159, Contribution: 0.0219
# Wavelength: 2188, Contribution: 0.0219
# Wavelength: 2190, Contribution: 0.0219
# Wavelength: 2158, Contribution: 0.0219
# Wavelength: 2219, Contribution: 0.0219
# Wavelength: 2187, Contribution: 0.0219
# Wavelength: 2220, Contribution: 0.0219
#
# PC2:
# Wavelength: 670, Contribution: 0.0492
# Wavelength: 671, Contribution: 0.0491
# Wavelength: 669, Contribution: 0.0491
# Wavelength: 668, Contribution: 0.0490
# Wavelength: 672, Contribution: 0.0490
# Wavelength: 667, Contribution: 0.0489
# Wavelength: 673, Contribution: 0.0489
# Wavelength: 674, Contribution: 0.0488
# Wavelength: 666, Contribution: 0.0487
# Wavelength: 675, Contribution: 0.0487
#
# PC3:
# Wavelength: 408, Contribution: 0.0474
# Wavelength: 407, Contribution: 0.0455
# Wavelength: 402, Contribution: 0.0455
# Wavelength: 409, Contribution: 0.0450
# Wavelength: 406, Contribution: 0.0442
# Wavelength: 401, Contribution: 0.0435
# Wavelength: 405, Contribution: 0.0433
# Wavelength: 400, Contribution: 0.0430
# Wavelength: 399, Contribution: 0.0428
# Wavelength: 403, Contribution: 0.0425
#
# PC4:
# Wavelength: 408, Contribution: 0.0774
# Wavelength: 402, Contribution: 0.0753
# Wavelength: 407, Contribution: 0.0751
# Wavelength: 405, Contribution: 0.0746
# Wavelength: 406, Contribution: 0.0745
# Wavelength: 401, Contribution: 0.0744
# Wavelength: 409, Contribution: 0.0732
# Wavelength: 412, Contribution: 0.0731
# Wavelength: 413, Contribution: 0.0728
# Wavelength: 411, Contribution: 0.0726
#
# PC5:
# Wavelength: 359, Contribution: 0.0976
# Wavelength: 366, Contribution: 0.0916
# Wavelength: 367, Contribution: 0.0903
# Wavelength: 351, Contribution: 0.0833
# Wavelength: 352, Contribution: 0.0825
# Wavelength: 365, Contribution: 0.0802
# Wavelength: 371, Contribution: 0.0768
# Wavelength: 358, Contribution: 0.0758
# Wavelength: 346, Contribution: 0.0756
# Wavelength: 368, Contribution: 0.0743
#
# Day 4:
#
# PC1:
# Wavelength: 2254, Contribution: 0.0220
# Wavelength: 2479, Contribution: 0.0220
# Wavelength: 2253, Contribution: 0.0220
# Wavelength: 2305, Contribution: 0.0220
# Wavelength: 2269, Contribution: 0.0220
# Wavelength: 2270, Contribution: 0.0220
# Wavelength: 1726, Contribution: 0.0220
# Wavelength: 1725, Contribution: 0.0220
# Wavelength: 1724, Contribution: 0.0220
# Wavelength: 1723, Contribution: 0.0220
#
# PC2:
# Wavelength: 348, Contribution: 0.1088
# Wavelength: 349, Contribution: 0.1082
# Wavelength: 347, Contribution: 0.1081
# Wavelength: 350, Contribution: 0.1077
# Wavelength: 346, Contribution: 0.1076
# Wavelength: 351, Contribution: 0.1072
# Wavelength: 352, Contribution: 0.1066
# Wavelength: 353, Contribution: 0.1060
# Wavelength: 354, Contribution: 0.1057
# Wavelength: 355, Contribution: 0.1048
#
# PC3:
# Wavelength: 2487, Contribution: 0.1309
# Wavelength: 2488, Contribution: 0.0958
# Wavelength: 2494, Contribution: 0.0810
# Wavelength: 2486, Contribution: 0.0801
# Wavelength: 2493, Contribution: 0.0718
# Wavelength: 653, Contribution: 0.0526
# Wavelength: 652, Contribution: 0.0523
# Wavelength: 654, Contribution: 0.0521
# Wavelength: 651, Contribution: 0.0515
# Wavelength: 655, Contribution: 0.0512
#
# PC4:
# Wavelength: 2494, Contribution: 0.0890
# Wavelength: 2433, Contribution: 0.0853
# Wavelength: 2493, Contribution: 0.0731
# Wavelength: 346, Contribution: -0.0725
# Wavelength: 347, Contribution: -0.0717
# Wavelength: 2502, Contribution: 0.0710
# Wavelength: 348, Contribution: -0.0702
# Wavelength: 2426, Contribution: 0.0701
# Wavelength: 349, Contribution: -0.0691
# Wavelength: 2495, Contribution: 0.0686
#
# PC5:
# Wavelength: 2501, Contribution: 0.1476
# Wavelength: 2473, Contribution: 0.1458
# Wavelength: 2474, Contribution: 0.1415
# Wavelength: 2500, Contribution: 0.1400
# Wavelength: 2487, Contribution: 0.1263
# Wavelength: 2480, Contribution: 0.1176
# Wavelength: 2498, Contribution: -0.1169
# Wavelength: 2494, Contribution: -0.1162
# Wavelength: 2497, Contribution: -0.1087
# Wavelength: 2453, Contribution: 0.1075
#
# Day 5:
#
# PC1:
# Wavelength: 473, Contribution: 0.0219
# Wavelength: 472, Contribution: 0.0219
# Wavelength: 471, Contribution: 0.0219
# Wavelength: 470, Contribution: 0.0219
# Wavelength: 474, Contribution: 0.0219
# Wavelength: 489, Contribution: 0.0219
# Wavelength: 488, Contribution: 0.0219
# Wavelength: 490, Contribution: 0.0219
# Wavelength: 487, Contribution: 0.0219
# Wavelength: 492, Contribution: 0.0219
#
# PC2:
# Wavelength: 1905, Contribution: 0.0493
# Wavelength: 1906, Contribution: 0.0492
# Wavelength: 1904, Contribution: 0.0492
# Wavelength: 1907, Contribution: 0.0491
# Wavelength: 1903, Contribution: 0.0488
# Wavelength: 1908, Contribution: 0.0487
# Wavelength: 1902, Contribution: 0.0485
# Wavelength: 1909, Contribution: 0.0481
# Wavelength: 1910, Contribution: 0.0476
# Wavelength: 1911, Contribution: 0.0466
#
# PC3:
# Wavelength: 2507, Contribution: 0.0444
# Wavelength: 2500, Contribution: 0.0430
# Wavelength: 2501, Contribution: 0.0428
# Wavelength: 2506, Contribution: 0.0412
# Wavelength: 1902, Contribution: -0.0412
# Wavelength: 2502, Contribution: 0.0407
# Wavelength: 1903, Contribution: -0.0397
# Wavelength: 2503, Contribution: 0.0388
# Wavelength: 1904, Contribution: -0.0381
# Wavelength: 2505, Contribution: 0.0374
#
# PC4:
# Wavelength: 1889, Contribution: 0.0689
# Wavelength: 1890, Contribution: 0.0687
# Wavelength: 2487, Contribution: 0.0684
# Wavelength: 1888, Contribution: 0.0681
# Wavelength: 1891, Contribution: 0.0681
# Wavelength: 1892, Contribution: 0.0676
# Wavelength: 1887, Contribution: 0.0674
# Wavelength: 1893, Contribution: 0.0673
# Wavelength: 1894, Contribution: 0.0667
# Wavelength: 1886, Contribution: 0.0667
#
# PC5:
# Wavelength: 2485, Contribution: 0.0601
# Wavelength: 365, Contribution: -0.0601
# Wavelength: 2486, Contribution: 0.0577
# Wavelength: 366, Contribution: -0.0564
# Wavelength: 364, Contribution: -0.0550
# Wavelength: 2487, Contribution: 0.0547
# Wavelength: 368, Contribution: -0.0539
# Wavelength: 367, Contribution: -0.0537
# Wavelength: 2484, Contribution: 0.0511
# Wavelength: 369, Contribution: -0.0490
#
# Day 6:
#
# PC1:
# Wavelength: 359, Contribution: 0.0234
# Wavelength: 360, Contribution: 0.0233
# Wavelength: 358, Contribution: 0.0233
# Wavelength: 521, Contribution: 0.0233
# Wavelength: 522, Contribution: 0.0233
# Wavelength: 524, Contribution: 0.0233
# Wavelength: 523, Contribution: 0.0233
# Wavelength: 519, Contribution: 0.0233
# Wavelength: 525, Contribution: 0.0233
# Wavelength: 520, Contribution: 0.0233
#
# PC2:
# Wavelength: 1902, Contribution: 0.0412
# Wavelength: 1903, Contribution: 0.0405
# Wavelength: 1904, Contribution: 0.0400
# Wavelength: 2487, Contribution: 0.0398
# Wavelength: 1905, Contribution: 0.0395
# Wavelength: 1910, Contribution: 0.0394
# Wavelength: 1940, Contribution: 0.0394
# Wavelength: 1906, Contribution: 0.0393
# Wavelength: 2502, Contribution: 0.0393
# Wavelength: 1911, Contribution: 0.0392
#
# PC3:
# Wavelength: 2507, Contribution: 0.0773
# Wavelength: 2506, Contribution: 0.0568
# Wavelength: 1274, Contribution: -0.0441
# Wavelength: 1273, Contribution: -0.0441
# Wavelength: 1272, Contribution: -0.0441
# Wavelength: 1282, Contribution: -0.0441
# Wavelength: 1280, Contribution: -0.0441
# Wavelength: 1277, Contribution: -0.0440
# Wavelength: 1278, Contribution: -0.0440
# Wavelength: 1283, Contribution: -0.0440
#
# PC4:
# Wavelength: 2478, Contribution: 0.1199
# Wavelength: 2474, Contribution: -0.1178
# Wavelength: 2491, Contribution: -0.1168
# Wavelength: 2490, Contribution: -0.1100
# Wavelength: 2489, Contribution: -0.0952
# Wavelength: 2473, Contribution: -0.0930
# Wavelength: 2475, Contribution: -0.0910
# Wavelength: 2433, Contribution: -0.0880
# Wavelength: 2492, Contribution: -0.0868
# Wavelength: 2479, Contribution: 0.0850
#
# PC5:
# Wavelength: 2494, Contribution: 0.1305
# Wavelength: 2495, Contribution: 0.1247
# Wavelength: 2455, Contribution: 0.1175
# Wavelength: 2456, Contribution: 0.1121
# Wavelength: 2496, Contribution: 0.1051
# Wavelength: 2489, Contribution: -0.1040
# Wavelength: 2454, Contribution: 0.1039
# Wavelength: 2488, Contribution: -0.0999
# Wavelength: 2487, Contribution: -0.0949
# Wavelength: 2493, Contribution: 0.0924
